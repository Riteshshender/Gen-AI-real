# %%
import pandas as pd
import numpy as np

# %% [markdown]
# step 1

# %%
data1=pd.read_csv('/content/data.csv')

# %%
data1
# Out:
#     SrNo  Patient_Id Fever_Mild Fever_Low Fever_High         DOB Cough_Mild  \
# 0      1           1          Y         N          N  04-05-1996          N
# 1      2           2          Y         N          N  26-08-1980          N
# 2      3           3          Y         N          N  31-11-2003          N
# 3      4           4          Y         N          N  27-06-1999          N
# 4      5           5          Y         N          N  21-07-2000          N
# 5      6           6          Y         N          N  07-03-2013          N
# 6      7           7          Y         N          N  03-12-2005          N
# 7      8           8          Y         N          N  23-07-2018          N
# 8      9           9          Y         N          N  08-10-1980          N
# 9     10          10          Y         N          N  25-04-2002          N
# 10    11          11          Y         N          N  09-09-2007          N
# ...

# %%
symptoms = {
    'S1': {'Fever': ['Mild', 'Low', 'High']},
    'S2': {'Cough': ['Mild', 'Low', 'High']},
    'S3': {'Cold': ['Mild', 'Low', 'High']}
}

print(symptoms)
# Out:
# {'S1': {'Fever': ['Mild', 'Low', 'High']}, 'S2': {'Cough': ['Mild', 'Low', 'High']}, 'S3': {'Cold': ['Mild', 'Low', 'High']}}

# %% [markdown]
# step 2

# %%
# Extract unique symptoms from the "Other_Symptoms" column
unique_symptoms = df['Other_Symptoms'].str.split(',').explode().str.strip().unique()

# Track losses (symptoms not found in the dictionary)
loss = [symptom for symptom in unique_symptoms if not any(symptom in info for info in symptoms.values())]

# Add new symptoms to the dictionary
for symptom in loss:
    new_group = f'Symptom{len(symptoms) + 1}'
    symptoms[new_group] = {symptom: None}

# Print the updated symptoms dictionary and loss
print("Updated Symptoms Dictionary:")
for group, info in symptoms.items():
    print(f"{group}: {info}")

print("\nLoss (new symptoms added to the dictionary):")
print(loss)
# Out:
# Updated Symptoms Dictionary:
# S1: {'Fever': ['Mild', 'Low', 'High']}
# S2: {'Cough': ['Mild', 'Low', 'High']}
# S3: {'Cold': ['Mild', 'Low', 'High']}
# Symptom4: {'Body Ache': None}
# Symptom5: {'Shivering': None}
# Symptom6: {'Head Ache': None}
# Symptom7: {'Nausia': None}
# Symptom8: {'Sickness': None}
# Symptom9: {'Vertigo': None}
# Symptom10: {'Vomitting': None}
# Symptom11: {'Nose Bleed': None}
#
# Loss (new symptoms added to the dictionary):
# ['Body Ache', 'Shivering', 'Head Ache', 'Nausia', 'Sickness', 'Vertigo', 'Vomitting', 'Nose Bleed']

# %%
loss_number = len(loss) / len(symptoms) if symptoms else 0
print("\nLoss as a number:", loss_number)
# Out:
# Loss as a number: 0.7272727272727273

# %% [markdown]
# step 3

# %%
# Update symptoms without severity levels
for info in symptoms.values():
    for symptom in info:
        if not isinstance(info[symptom], list):
            info[symptom] = ['Mild', 'Low', 'High']

# Print the updated dictionary
print("Updated Symptoms Dictionary with Severity Levels:")
for group, info in symptoms.items():
    print(f"{group}: {info}")
# Out:
# Updated Symptoms Dictionary with Severity Levels:
# S1: {'Fever': ['Mild', 'Low', 'High']}
# S2: {'Cough': ['Mild', 'Low', 'High']}
# S3: {'Cold': ['Mild', 'Low', 'High']}
# Symptom4: {'Body Ache': ['Mild', 'Low', 'High']}
# Symptom5: {'Shivering': ['Mild', 'Low', 'High']}
# Symptom6: {'Head Ache': ['Mild', 'Low', 'High']}
# Symptom7: {'Nausia': ['Mild', 'Low', 'High']}
# Symptom8: {'Sickness': ['Mild', 'Low', 'High']}
# Symptom9: {'Vertigo': ['Mild', 'Low', 'High']}
# Symptom10: {'Vomitting': ['Mild', 'Low', 'High']}
# Symptom11: {'Nose Bleed': ['Mild', 'Low', 'High']}

# %%
loss_number = len(loss) / len(symptoms) if symptoms else 0
print("\nLoss as a number:", loss_number)
# Out:
# Loss as a number: 0.7272727272727273

# %%
import json
with open("symptoms_dict.json", 'w') as f:
        json.dump(symptoms, f, indent=4)

# %% [markdown]
# step 4
